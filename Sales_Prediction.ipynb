# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Administrator\Desktop\Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.head(200)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.shape
# Out:
# (200, 5)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
fig, axs = plt.subplots(3, figsize=(5, 5),)
plt1 = sns.boxplot(df['TV'], ax=axs[0], orient='h')
plt1.set_xlabel('(TV)')

plt2 = sns.boxplot(df['Newspaper'], ax=axs[1], orient='h')
plt2.set_xlabel('(Newspaper)') 

plt3 = sns.boxplot(df['Radio'], ax=axs[2], orient='h')
plt3.set_xlabel('(Radio)') 




plt.tight_layout()

plt.show()

# %%
sns.distplot(df['TV'])
# Out:
# <Axes: xlabel='TV', ylabel='Density'>

# %%
sns.distplot(df['Radio'])
# Out:
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
sns.distplot(df['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
iqr = df.Newspaper.quantile(0.75) - df.Newspaper.quantile(0.25)

# %%
l_bridge = df["Newspaper"].quantile(0.25) - (iqr*1.5)
u_bridge = df["Newspaper"].quantile(0.75) + (iqr*1.5)
print(l_bridge)
print(u_bridge)
# Out:
# -35.775000000000006
# 93.625

# %%
data = df.copy()

# %%
data.loc[data['Newspaper']>=93, 'Newspaper']=93
ax = sns.boxplot(data['Newspaper'], orient='h')
ax.set_xlabel('Newspaper')
# Out:
# Text(0.5, 0, 'Newspaper')

# %%
sx = sns.boxplot(data['Sales'], orient='h');
sx.set_xlabel('Sales')
# Out:
# Text(0.5, 0, 'Sales')

# %%
sns.pairplot(data, x_vars = ['TV', 'Newspaper', 'Radio'],
            y_vars = 'Sales', height = 6, aspect = 0.5, kind = 'scatter')
plt.show()

# %%
sns.heatmap(data.corr(), cmap = "YlGnBu", annot = True)
plt.show()

# %%
important_features = list(df.corr()['Sales'][(df.corr()['Sales']>+0.5)|(df.corr()['Sales']<-0.5)].index)
print(important_features)
# Out:
# ['TV', 'Radio', 'Sales']

# %%
x = data['TV']
y = data['Sales']

# %%
x = x.values.reshape(-1, 1)

# %%
x
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
# ...

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
print(x.shape, y.shape)
# Out:
# (200, 1) (200,)

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (134, 1) (134,)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
knn = KNeighborsRegressor().fit(x_train, y_train)
knn
# Out:
# KNeighborsRegressor()

# %%
knn_train_pred = knn.predict(x_train)
knn_test_pred = knn.predict(x_test)
print(knn_train_pred, knn_test_pred)
# Out:
# [18.52 12.96 17.54 15.96 20.98 14.48 17.6  18.44  9.98 12.96 12.96 20.5
#  14.66 20.98 18.44 16.14  9.98  7.22 14.26 14.06 21.9   9.94 14.5  14.74
#  15.7  13.8  19.16 17.7  22.1  11.44 13.36 20.14 18.56  7.    7.22 14.26
#  16.3  19.4  12.96 15.28  9.94 14.06 20.96 14.66 14.26 15.62 20.5  14.36
#  15.28  6.92 10.18 17.7  11.2  12.8  14.5  12.44 11.22  9.64 10.88 13.72
#   7.22 18.52 18.36 12.38  4.56  7.88 11.28 15.2  14.26 14.36 10.   12.38
#  12.8  18.78  9.94  7.88 12.38  7.22 11.1  14.34 19.34 19.4  11.44 11.22
#  14.14  4.56 12.14 10.88  4.56 11.22 18.78  6.12  9.94 18.92  7.88  7.88
#  11.62  9.64 15.28 18.92 18.44 18.52 20.14 11.28  7.88  5.7  19.34 20.14
#  19.4  15.62 11.22 15.7  18.44 19.16 18.9  15.28  9.8  11.44  9.98 17.66
#  14.82 13.38 16.42 20.14 11.28 12.8  20.14 12.24  7.22 11.1  20.36 12.16
#  20.98 14.92] [17.52 14.26 16.36 19.08  7.88 11.28 10.5  14.94 10.   12.96  8.6  11.38
#  14.5  18.44  7.22 21.9  12.66 20.14 20.14 15.28  7.    5.7  12.66 18.52
# ...

# %%
Result = pd.DataFrame(columns = ["Model", "Train R2", "Test R2", "Test RMSE", "Variance"])

# %%
r2 = r2_score(y_test, knn_test_pred)
r2_train = r2_score(y_train, knn_train_pred)
rmse = np.sqrt(mean_squared_error(y_test, knn_test_pred))
variance = r2_train - r2
Result = Result.append({"Model":"K-Nearest Neighbors", "Train R2":r2_train, "Test R2":r2, "Test RMSE":rmse, 
                       "Variance":variance}, ignore_index = True)
print("R2: ", r2)
print("RMSE: ", rmse)
# Out:
# R2:  0.42664309970816294
# RMSE:  3.966478477837931

# %%
Result.head()
# Out:
#                  Model  Train R2   Test R2  Test RMSE  Variance
# 0  K-Nearest Neighbors   0.68829  0.426643   3.966478  0.261647
# 1  K-Nearest Neighbors   0.68829  0.426643   3.966478  0.261647

# %%
svr = SVR().fit(x_train, y_train)
svr
# Out:
# SVR()

# %%
svr_train_pred = svr.predict(x_train)
svr_test_pred = svr.predict(x_test)
print(svr_train_pred, svr_test_pred)
# Out:
# [18.65258002 10.93641925 18.04922182 16.56837495 18.10332228 15.19151796
#  19.00526433 18.33816214 11.68879012 11.02181675 10.86213906 19.05860169
#  14.84035967 17.96862361 18.35246076 16.12347859 11.673304    7.6103557
#  14.06021541 12.67025725 18.99972001  8.74142929 14.195735   18.22954143
#  12.78443003 12.59926129 17.59144205 17.06552015 19.02656577 10.58019341
#  12.36104572 18.72321397 17.33769901  7.44910897  7.6103557  12.92886478
#  18.13589992 17.51474239 10.8809116  16.4086011   8.72912136 12.65144685
#  18.43675931 14.80004001 12.96600345 15.69243157 19.04860051 14.92848131
#  16.51766191  7.40004    11.72840779 17.07245023  9.93726917 12.14919856
#  14.26821224 12.22938112 11.38563647  9.04647237 11.87867713 13.69205611
#   7.71606154 18.76369808 17.77725409 12.26060312  7.19194824  7.98598004
#  10.54898338 15.48287133 12.87816032 14.92848131  9.47912189 12.34765026
#  13.36032598 17.8252714   8.66170605  8.17491514 12.33964318  7.67549579
# ...

# %%
r2 = r2_score(y_test, svr_test_pred)
r2_train = r2_score(y_train, svr_train_pred)
rmse = np.sqrt(mean_squared_error(y_test, svr_test_pred))
variance = r2_train - r2
Result = Result.append({"Model":"Support Vector Machine", "Train R2":r2_train, "Test R2":r2, "Test RMSE":rmse, 
                       "Variance":variance}, ignore_index = True)
print("R2: ", r2)
print("RMSE: ", rmse)
# Out:
# R2:  0.5431696775412593
# RMSE:  3.5405443736342512

# %%
Result.head()
# Out:
#                     Model  Train R2   Test R2  Test RMSE  Variance
# 0     K-Nearest Neighbors  0.688290  0.426643   3.966478  0.261647
# 1     K-Nearest Neighbors  0.688290  0.426643   3.966478  0.261647
# 2  Support Vector Machine  0.621371  0.543170   3.540544  0.078201

# %%
import statsmodels.api as sm

# %%
x_train_constant = sm.add_constant(x_train)
model = sm.OLS(y_train, x_train_constant).fit()
model.params
# Out:
# const    6.939874
# x1       0.048588
# dtype: float64

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.624
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     219.5
# Date:                Sun, 04 Jun 2023   Prob (F-statistic):           7.38e-30
# Time:                        15:27:52   Log-Likelihood:                -345.11
# No. Observations:                 134   AIC:                             694.2
# Df Residuals:                     132   BIC:                             700.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9399      0.551     12.602      0.000       5.851       8.029
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 6.9955 + 0.0241 * x_train, 'y')
plt.show()

# %%
y_train_pred = model.predict(x_train_constant)
res = (y_train - y_train_pred)
res
# Out:
# 102   -5.754326
# 86     1.352836
# 100   -6.045920
# 9     -6.047823
# 42    -0.505409
#          ...
# 156    3.797682
# 183    5.286121
# 143   -1.622214
# 30     0.228603
# 173   -3.422150
# Name: Sales, Length: 134, dtype: float64

# %%
y_train_pred
# Out:
# array([20.55432555, 10.64716369, 17.74591968, 16.64782327, 21.20540926,
#        15.72464488, 19.84493583, 18.01801437, 11.61407159, 10.73948153,
#        10.56942235, 19.3493348 , 15.47684436, 21.3414566 , 18.03259087,
#        16.35143442, 11.58977742,  7.77559299, 14.87434898, 13.33895754,
#        19.02865177,  8.79594806, 14.98610216, 17.91112003, 13.50901672,
#        13.22720437, 17.37178949, 16.98794163, 19.13068728, 10.29246883,
#        12.81906234, 18.47474474, 17.18229498,  7.57638081,  7.77559299,
#        13.7082289 , 17.82366102, 17.31348349, 10.58885769, 16.54092893,
#         8.78623039, 13.30980454, 20.8361379 , 15.44769136, 13.75681724,
#        16.06476323, 19.63600598, 15.5400092 , 16.61381144,  7.50835714,
#        11.67723643, 16.99280047,  9.73370296, 12.42549681, 15.04440816,
#        12.57612066, 11.17677656,  9.03403091, 11.92989578, 14.54880713,
#         7.892205  , 20.38426637, 17.5175545 , 12.63442666,  7.13908578,
# ...

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
fig.suptitle("Error Terms", fontsize = 15)
plt.xlabel('Difference in y_train and y_train_pred', fontsize = 15)
plt.show()

# %%
plt.scatter(x_train, res)
plt.show()

# %%
x_test_constant = sm.add_constant(x_test)
y_pred = model.predict(x_test_constant)
y_pred
# Out:
# array([17.17743615, 13.70337007, 16.22510475, 19.71374732,  8.24204102,
#        10.15156265,  9.67053812, 13.80540558,  9.53934961, 10.59857535,
#         8.4704062 ,  9.96692698, 14.88406665, 17.9791437 ,  7.80960482,
#        19.00921644, 12.27487297, 18.60593324, 18.56706258, 16.43403459,
#         7.58123964,  7.34801563, 12.27487297, 20.39398404,  7.76101649,
#        12.92109785, 16.06962207, 20.23850136, 10.8366582 , 13.55760506,
#        14.93265499, 18.60593324,  7.85333433, 18.59135674, 16.77901178,
#        18.21722655, 17.74591968, 19.27159346, 16.60409377, 15.92385706,
#        17.12398897, 17.473825  , 18.68367458, 10.65202252, 19.8255005 ,
#         9.83573847, 12.15826096, 15.81210388,  7.35773329, 16.85675312,
#        13.71794657, 18.33383856, 13.88314692, 10.65202252, 14.2135476 ,
#         9.10205458,  9.28669026, 19.90810067, 16.32714025, 10.60829302,
#        16.64782327, 21.01591475,  7.31886262, 19.70402965,  8.09627601,
#        20.75353773])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 3.372868503022278

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.5854149293824603

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, 6.9955 + 0.541 * x_test, 'y')
plt.show()
